# %%
import pandas as pd
from google.colab import drive
import matplotlib.pyplot as plt
import seaborn as sns
import geopandas as gpd

# %%
# 25-plr-producao-renovavel
drive.mount('/content/drive')
df = pd.read_parquet('/content/drive/MyDrive/Colab Notebooks/tese/25-plr-producao-renovavel.parquet')
print(df.head())
# Out:
# Mounted at /content/drive
#     ano semestre         concelho  potencia_de_ligacao  \
# 0  2021        1          Cadaval                 2000
# 1  2021        1            Moura                 2860
# 2  2021        1         Estremoz                 5900
# 3  2022        1  Figueira da Foz                    0
# 4  2022        1         Estremoz                14800
#
#    pedidos_de_ligacao_a_rede_executados codconcelho
# 0                                   1.0        1104
# 1                                   1.0        0210
# 2                                   1.0        0704
# 3                                   1.0        0605
# 4                                   1.0        0704
