# %%
# %clear

# %%
import pandas as pd
from google.colab import drive
import matplotlib.pyplot as plt
import seaborn as sns
import geopandas as gpd
import math
from shapely.geometry import Point
from pyproj import CRS

# %%
drive.mount('/content/drive')
excel_df = pd.read_excel('/content/drive/MyDrive/Colab Notebooks/tese/censos.xlsx')
excel_df
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#      Unnamed: 0  \
# 0            PT
# 1             1
# 2            11
# 3           111
# 4          1601
# ...         ...
# 3434     310905
# 3435       3110
# 3436     311001
# 3437     311002
# 3438     311003
#
#       População residente (N.º) por Local de residência à data dos Censos [2021] (NUTS - 2024), Sexo e Grupo etário (Por ciclos de vida); Decenal
# 0                                              10343066
# 1                                               9855909
# 2                                               3586586
# 3                                                231266
# 4                                                 20718
# ...                                                 ...
# 3434                                                680
# 3435                                               4865
# 3436                                               1034
# 3437                                               1043
# 3438                                               2788
#
# [3439 rows x 2 columns]
